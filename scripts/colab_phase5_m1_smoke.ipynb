# %% [markdown]
# # Phase 5 M1 Smoke (Branch Only)
#
# This notebook checks out `phase5-m1-role-energy-stack` and runs the synthetic M1 smoke. It is not a Phase 5 graduation run.

# %%
# !rm -rf /content/Neuro-AI
# !git clone https://github.com/Dypatterson/Neuro-AI.git /content/Neuro-AI
# %cd /content/Neuro-AI
# !git checkout phase5-m1-role-energy-stack
# !git log --oneline -1

# %%
import torch
print('torch', torch.__version__)
print('cuda available', torch.cuda.is_available())
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device', DEVICE)

# %%
# !PYTHONPATH=src:. python scripts/phase5_m1_local_smoke.py --device {DEVICE} --output /content/phase5_m1_smoke.json

# %%
import json
from pathlib import Path
payload = json.loads(Path('/content/phase5_m1_smoke.json').read_text())
payload
